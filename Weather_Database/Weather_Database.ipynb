# %%
# Import Dep 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time# Imports and requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from citipy import citipy
from datetime import datetime
from scipy.stats import linregress

#Import the requests library
import requests

#Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats,lngs)

# %%
# Add lotitude and longitude to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding cities.
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 773

# %%
#Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval    ")

# Create counters.
record_count = 1
set_count =1


# Loop through all the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = city_url = url + "&q=" + city
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                        })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# Processing Record 1 of Set 1 | nome
# Processing Record 2 of Set 1 | brunsbuttel
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | tomatlan
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | eyl
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 11 of Set 1 | zhigansk
# Processing Record 12 of Set 1 | carnarvon
# Processing Record 13 of Set 1 | krasnoselkup
# Processing Record 14 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | narsaq
# Processing Record 21 of Set 1 | barranco
# Processing Record 22 of Set 1 | menongue
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | port hardy
# Processing Record 28 of Set 1 | galgani
# City not found. Skipping...
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | coihaique
# Processing Record 31 of Set 1 | tir pol
# City not found. Skipping...
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | omboue
# Processing Record 34 of Set 1 | stoughton
# Processing Record 35 of Set 1 | klaksvik
# Processing Record 36 of Set 1 | verkh-chebula
# Processing Record 37 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 1 | clyde river
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | uglegorsk
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | manbij
# Processing Record 44 of Set 1 | tuatapere
# Processing Record 45 of Set 1 | turayf
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | caranavi
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | khandyga
# Processing Record 50 of Set 1 | iqaluit
# Processing Record 1 of Set 2 | fare
# Processing Record 2 of Set 2 | saint-philippe
# Processing Record 3 of Set 2 | bambous virieux
# Processing Record 4 of Set 2 | bonavista
# Processing Record 5 of Set 2 | saint george
# Processing Record 6 of Set 2 | richards bay
# Processing Record 7 of Set 2 | vao
# Processing Record 8 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 2 | barra do garcas
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | faya
# Processing Record 12 of Set 2 | mount gambier
# Processing Record 13 of Set 2 | baykit
# Processing Record 14 of Set 2 | manuk mangkaw
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | collie
# Processing Record 17 of Set 2 | hilo
# Processing Record 18 of Set 2 | presidencia roque saenz pena
# Processing Record 19 of Set 2 | miquelon
# Processing Record 20 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 21 of Set 2 | hearst
# Processing Record 22 of Set 2 | belmonte
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | talaya
# Processing Record 25 of Set 2 | manado
# Processing Record 26 of Set 2 | kruisfontein
# Processing Record 27 of Set 2 | guerrero negro
# Processing Record 28 of Set 2 | tete
# Processing Record 29 of Set 2 | nanortalik
# Processing Record 30 of Set 2 | avarua
# Processing Record 31 of Set 2 | fiumicino
# Processing Record 32 of Set 2 | hambantota
# Processing Record 33 of Set 2 | esperance
# Processing Record 34 of Set 2 | ilulissat
# Processing Record 35 of Set 2 | port alfred
# Processing Record 36 of Set 2 | lata
# Processing Record 37 of Set 2 | loubomo
# Processing Record 38 of Set 2 | yar-sale
# Processing Record 39 of Set 2 | upernavik
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | raga
# Processing Record 42 of Set 2 | codrington
# Processing Record 43 of Set 2 | xiangdong
# City not found. Skipping...
# Processing Record 44 of Set 2 | rawson
# Processing Record 45 of Set 2 | ostrovnoy
# Processing Record 46 of Set 2 | lundazi
# Processing Record 47 of Set 2 | sorland
# Processing Record 48 of Set 2 | kalmunai
# Processing Record 49 of Set 2 | palmer
# Processing Record 50 of Set 2 | ribeira grande
# Processing Record 1 of Set 3 | talnakh
# Processing Record 2 of Set 3 | nalut
# Processing Record 3 of Set 3 | linkoping
# Processing Record 4 of Set 3 | thompson
# Processing Record 5 of Set 3 | ancud
# Processing Record 6 of Set 3 | dudinka
# Processing Record 7 of Set 3 | alamosa
# Processing Record 8 of Set 3 | claremore
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | bethel
# Processing Record 11 of Set 3 | marystown
# Processing Record 12 of Set 3 | los llanos de aridane
# Processing Record 13 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 14 of Set 3 | chara
# Processing Record 15 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 3 | khatanga
# Processing Record 17 of Set 3 | hamilton
# Processing Record 18 of Set 3 | nouadhibou
# Processing Record 19 of Set 3 | high level
# Processing Record 20 of Set 3 | provideniya
# Processing Record 21 of Set 3 | dikson
# Processing Record 22 of Set 3 | muros
# Processing Record 23 of Set 3 | escanaba
# Processing Record 24 of Set 3 | esna
# Processing Record 25 of Set 3 | cavalcante
# Processing Record 26 of Set 3 | kavieng
# Processing Record 27 of Set 3 | pontes e lacerda
# Processing Record 28 of Set 3 | cabo san lucas
# Processing Record 29 of Set 3 | geraldton
# Processing Record 30 of Set 3 | paciran
# Processing Record 31 of Set 3 | san quintin
# Processing Record 32 of Set 3 | kaitangata
# Processing Record 33 of Set 3 | poum
# Processing Record 34 of Set 3 | sao joao da barra
# Processing Record 35 of Set 3 | najran
# Processing Record 36 of Set 3 | husavik
# Processing Record 37 of Set 3 | norden
# Processing Record 38 of Set 3 | dingle
# Processing Record 39 of Set 3 | victoria
# Processing Record 40 of Set 3 | matucana
# Processing Record 41 of Set 3 | the valley
# Processing Record 42 of Set 3 | labuhan
# Processing Record 43 of Set 3 | mirnyy
# Processing Record 44 of Set 3 | chuy
# Processing Record 45 of Set 3 | olesnica
# Processing Record 46 of Set 3 | rabo de peixe
# Processing Record 47 of Set 3 | shunyi
# Processing Record 48 of Set 3 | dingzhou
# Processing Record 49 of Set 3 | mar del plata
# Processing Record 50 of Set 3 | yarada
# Processing Record 1 of Set 4 | namibe
# Processing Record 2 of Set 4 | porosozero
# Processing Record 3 of Set 4 | hobart
# Processing Record 4 of Set 4 | caravelas
# Processing Record 5 of Set 4 | yulara
# Processing Record 6 of Set 4 | pitimbu
# Processing Record 7 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 4 | eyrarbakki
# Processing Record 9 of Set 4 | vostok
# Processing Record 10 of Set 4 | nicoya
# Processing Record 11 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 12 of Set 4 | roald
# Processing Record 13 of Set 4 | pevek
# Processing Record 14 of Set 4 | aripuana
# Processing Record 15 of Set 4 | unai
# Processing Record 16 of Set 4 | san rafael
# Processing Record 17 of Set 4 | betsiamites
# Processing Record 18 of Set 4 | west bay
# Processing Record 19 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 20 of Set 4 | aldan
# Processing Record 21 of Set 4 | xiongyue
# Processing Record 22 of Set 4 | jamame
# Processing Record 23 of Set 4 | nkowakowa
# Processing Record 24 of Set 4 | maragogi
# Processing Record 25 of Set 4 | hwange
# Processing Record 26 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 4 | sovetskiy
# Processing Record 28 of Set 4 | palmas
# Processing Record 29 of Set 4 | dzaoudzi
# Processing Record 30 of Set 4 | gillette
# Processing Record 31 of Set 4 | ilinden
# Processing Record 32 of Set 4 | nelson bay
# Processing Record 33 of Set 4 | cape town
# Processing Record 34 of Set 4 | faanui
# Processing Record 35 of Set 4 | buala
# Processing Record 36 of Set 4 | san patricio
# Processing Record 37 of Set 4 | nanding
# Processing Record 38 of Set 4 | alamor
# Processing Record 39 of Set 4 | magadi
# Processing Record 40 of Set 4 | fortuna
# Processing Record 41 of Set 4 | laguna
# Processing Record 42 of Set 4 | jamestown
# Processing Record 43 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 4 | dolores
# Processing Record 45 of Set 4 | hasaki
# Processing Record 46 of Set 4 | pyay
# Processing Record 47 of Set 4 | aklavik
# Processing Record 48 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 4 | avera
# Processing Record 50 of Set 4 | port elizabeth
# Processing Record 1 of Set 5 | yellowknife
# Processing Record 2 of Set 5 | georgetown
# Processing Record 3 of Set 5 | grindavik
# Processing Record 4 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 5 | urucara
# Processing Record 6 of Set 5 | pemangkat
# Processing Record 7 of Set 5 | lebu
# Processing Record 8 of Set 5 | yola
# Processing Record 9 of Set 5 | haines junction
# Processing Record 10 of Set 5 | tha chang
# Processing Record 11 of Set 5 | aswan
# Processing Record 12 of Set 5 | rudbar
# Processing Record 13 of Set 5 | kodiak
# Processing Record 14 of Set 5 | pyaozerskiy
# Processing Record 15 of Set 5 | constitucion
# Processing Record 16 of Set 5 | kieta
# Processing Record 17 of Set 5 | ust-nera
# Processing Record 18 of Set 5 | saint anthony
# Processing Record 19 of Set 5 | meulaboh
# Processing Record 20 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 5 | mahon
# Processing Record 22 of Set 5 | sao filipe
# Processing Record 23 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 24 of Set 5 | yuxia
# Processing Record 25 of Set 5 | balakhninskiy
# Processing Record 26 of Set 5 | huaihua
# Processing Record 27 of Set 5 | grand gaube
# Processing Record 28 of Set 5 | garowe
# Processing Record 29 of Set 5 | bani walid
# Processing Record 30 of Set 5 | moyale
# Processing Record 31 of Set 5 | preobrazheniye
# Processing Record 32 of Set 5 | skuratovskiy
# Processing Record 33 of Set 5 | ust-kishert
# Processing Record 34 of Set 5 | leshukonskoye
# Processing Record 35 of Set 5 | bati
# Processing Record 36 of Set 5 | yilan
# Processing Record 37 of Set 5 | pisco
# Processing Record 38 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 5 | alaca
# Processing Record 40 of Set 5 | airai
# Processing Record 41 of Set 5 | doka
# Processing Record 42 of Set 5 | longyearbyen
# Processing Record 43 of Set 5 | monatele
# City not found. Skipping...
# Processing Record 44 of Set 5 | longavi
# Processing Record 45 of Set 5 | hervey bay
# Processing Record 46 of Set 5 | bengkulu
# Processing Record 47 of Set 5 | broome
# Processing Record 48 of Set 5 | aquidauana
# Processing Record 49 of Set 5 | ponta do sol
# Processing Record 50 of Set 5 | jaipur hat
# City not found. Skipping...
# Processing Record 1 of Set 6 | fairbanks
# Processing Record 2 of Set 6 | kathu
# Processing Record 3 of Set 6 | balikpapan
# Processing Record 4 of Set 6 | chokurdakh
# Processing Record 5 of Set 6 | port blair
# Processing Record 6 of Set 6 | alamo
# Processing Record 7 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 6 | kaniama
# Processing Record 9 of Set 6 | poddorye
# Processing Record 10 of Set 6 | tunceli
# Processing Record 11 of Set 6 | tiksi
# Processing Record 12 of Set 6 | calvia
# Processing Record 13 of Set 6 | mahebourg
# Processing Record 14 of Set 6 | half moon bay
# Processing Record 15 of Set 6 | tabou
# Processing Record 16 of Set 6 | mogadishu
# Processing Record 17 of Set 6 | tawau
# Processing Record 18 of Set 6 | mecca
# Processing Record 19 of Set 6 | ketchikan
# Processing Record 20 of Set 6 | pandan
# Processing Record 21 of Set 6 | nemuro
# Processing Record 22 of Set 6 | toppenish
# Processing Record 23 of Set 6 | lavrentiya
# Processing Record 24 of Set 6 | adrar
# Processing Record 25 of Set 6 | san cristobal
# Processing Record 26 of Set 6 | walvis bay
# Processing Record 27 of Set 6 | beringovskiy
# Processing Record 28 of Set 6 | matsumoto
# Processing Record 29 of Set 6 | port-cartier
# Processing Record 30 of Set 6 | ambilobe
# Processing Record 31 of Set 6 | ust-ishim
# Processing Record 32 of Set 6 | bandarbeyla
# Processing Record 33 of Set 6 | zeya
# Processing Record 34 of Set 6 | puerto leguizamo
# Processing Record 35 of Set 6 | bodrum
# Processing Record 36 of Set 6 | herre
# Processing Record 37 of Set 6 | sechura
# Processing Record 38 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 6 | weinan
# Processing Record 40 of Set 6 | ust-ilimsk
# Processing Record 41 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 42 of Set 6 | sitka
# Processing Record 43 of Set 6 | el alto
# Processing Record 44 of Set 6 | coria
# Processing Record 45 of Set 6 | swan river
# Processing Record 46 of Set 6 | thano bula khan
# City not found. Skipping...
# Processing Record 47 of Set 6 | edremit
# Processing Record 48 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 6 | padang
# Processing Record 50 of Set 6 | quatre cocos
# Processing Record 1 of Set 7 | kahului
# Processing Record 2 of Set 7 | matay
# Processing Record 3 of Set 7 | gemena
# Processing Record 4 of Set 7 | sarakhs
# Processing Record 5 of Set 7 | korla
# Processing Record 6 of Set 7 | port lincoln
# Processing Record 7 of Set 7 | tuktoyaktuk
# Processing Record 8 of Set 7 | havre
# Processing Record 9 of Set 7 | selikhino
# Processing Record 10 of Set 7 | katsuura
# Processing Record 11 of Set 7 | coahuayana
# Processing Record 12 of Set 7 | mount isa
# Processing Record 13 of Set 7 | souillac
# Processing Record 14 of Set 7 | denpasar
# Processing Record 15 of Set 7 | hami
# Processing Record 16 of Set 7 | karratha
# Processing Record 17 of Set 7 | samarai
# Processing Record 18 of Set 7 | camacari
# Processing Record 19 of Set 7 | gorontalo
# Processing Record 20 of Set 7 | saskylakh
# Processing Record 21 of Set 7 | ascension
# Processing Record 22 of Set 7 | svobodnyy
# Processing Record 23 of Set 7 | kutoarjo
# Processing Record 24 of Set 7 | kabo
# Processing Record 25 of Set 7 | emerald
# Processing Record 26 of Set 7 | santa isabel do rio negro
# Processing Record 27 of Set 7 | burnie
# Processing Record 28 of Set 7 | ngunguru
# Processing Record 29 of Set 7 | jalu
# Processing Record 30 of Set 7 | kawhia
# Processing Record 31 of Set 7 | assiniboia
# Processing Record 32 of Set 7 | sungaipenuh
# Processing Record 33 of Set 7 | kununurra
# Processing Record 34 of Set 7 | honningsvag
# Processing Record 35 of Set 7 | thaton
# Processing Record 36 of Set 7 | viedma
# Processing Record 37 of Set 7 | springbok
# Processing Record 38 of Set 7 | westport
# Processing Record 39 of Set 7 | kudahuvadhoo
# Processing Record 40 of Set 7 | sinnamary
# Processing Record 41 of Set 7 | moerai
# Processing Record 42 of Set 7 | urumqi
# Processing Record 43 of Set 7 | severo-kurilsk
# Processing Record 44 of Set 7 | okhotsk
# Processing Record 45 of Set 7 | teguise
# Processing Record 46 of Set 7 | altay
# Processing Record 47 of Set 7 | hobyo
# Processing Record 48 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 7 | ibanda
# Processing Record 50 of Set 7 | nagato
# Processing Record 1 of Set 8 | pak phanang
# Processing Record 2 of Set 8 | saint-pierre
# Processing Record 3 of Set 8 | izumo
# Processing Record 4 of Set 8 | mayor pablo lagerenza
# Processing Record 5 of Set 8 | deputatskiy
# Processing Record 6 of Set 8 | luderitz
# Processing Record 7 of Set 8 | tura
# Processing Record 8 of Set 8 | goderich
# Processing Record 9 of Set 8 | saint-denis
# Processing Record 10 of Set 8 | sioux lookout
# Processing Record 11 of Set 8 | kenai
# Processing Record 12 of Set 8 | lompoc
# Processing Record 13 of Set 8 | kamaishi
# Processing Record 14 of Set 8 | nabire
# Processing Record 15 of Set 8 | acapulco
# Processing Record 16 of Set 8 | lasa
# Processing Record 17 of Set 8 | pundaguitan
# Processing Record 18 of Set 8 | qaqortoq
# Processing Record 19 of Set 8 | pierre
# Processing Record 20 of Set 8 | brezno
# Processing Record 21 of Set 8 | terrasini
# Processing Record 22 of Set 8 | marzuq
# Processing Record 23 of Set 8 | ahipara
# Processing Record 24 of Set 8 | horta
# Processing Record 25 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 26 of Set 8 | tasiilaq
# Processing Record 27 of Set 8 | piopio
# Processing Record 28 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 8 | kiruna
# Processing Record 30 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 8 | isangel
# Processing Record 32 of Set 8 | maputo
# Processing Record 33 of Set 8 | yazoo city
# Processing Record 34 of Set 8 | barcelos
# Processing Record 35 of Set 8 | nsanje
# Processing Record 36 of Set 8 | kletnya
# Processing Record 37 of Set 8 | torbay
# Processing Record 38 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 8 | mineros
# Processing Record 40 of Set 8 | moron
# Processing Record 41 of Set 8 | bassar
# Processing Record 42 of Set 8 | belaya gora
# Processing Record 43 of Set 8 | jian
# Processing Record 44 of Set 8 | leningradskiy
# Processing Record 45 of Set 8 | kajaani
# Processing Record 46 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 48 of Set 8 | calama
# Processing Record 49 of Set 8 | lincoln
# Processing Record 50 of Set 8 | saquarema
# Processing Record 1 of Set 9 | luangwa
# Processing Record 2 of Set 9 | saldanha
# Processing Record 3 of Set 9 | suihua
# Processing Record 4 of Set 9 | necochea
# Processing Record 5 of Set 9 | birao
# Processing Record 6 of Set 9 | sambava
# Processing Record 7 of Set 9 | surt
# Processing Record 8 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 9 | paragominas
# Processing Record 10 of Set 9 | ucluelet
# Processing Record 11 of Set 9 | kuching
# Processing Record 12 of Set 9 | bend
# Processing Record 13 of Set 9 | namatanai
# Processing Record 14 of Set 9 | bangalore
# Processing Record 15 of Set 9 | guarapari
# Processing Record 16 of Set 9 | ternate
# Processing Record 17 of Set 9 | seoul
# Processing Record 18 of Set 9 | lubao
# Processing Record 19 of Set 9 | sayyan
# Processing Record 20 of Set 9 | tecoanapa
# Processing Record 21 of Set 9 | talcahuano
# Processing Record 22 of Set 9 | athabasca
# Processing Record 23 of Set 9 | taltal
# Processing Record 24 of Set 9 | druzhba
# Processing Record 25 of Set 9 | halifax
# Processing Record 26 of Set 9 | buraydah
# Processing Record 27 of Set 9 | maniitsoq
# Processing Record 28 of Set 9 | matara
# Processing Record 29 of Set 9 | asau
# Processing Record 30 of Set 9 | maxixe
# Processing Record 31 of Set 9 | gumia
# Processing Record 32 of Set 9 | novikovo
# Processing Record 33 of Set 9 | wladyslawowo
# Processing Record 34 of Set 9 | kuryk
# Processing Record 35 of Set 9 | camopi
# Processing Record 36 of Set 9 | narsipatnam
# Processing Record 37 of Set 9 | kourou
# Processing Record 38 of Set 9 | san francisco
# Processing Record 39 of Set 9 | jumla
# Processing Record 40 of Set 9 | santa cruz del norte
# Processing Record 41 of Set 9 | rognan
# Processing Record 42 of Set 9 | olot
# Processing Record 43 of Set 9 | dunmore town
# Processing Record 44 of Set 9 | chiang klang
# Processing Record 45 of Set 9 | bage
# Processing Record 46 of Set 9 | auburn hills
# Processing Record 47 of Set 9 | coihueco
# Processing Record 48 of Set 9 | mascote
# Processing Record 49 of Set 9 | banamba
# Processing Record 50 of Set 9 | chenzhou
# Processing Record 1 of Set 10 | nongstoin
# Processing Record 2 of Set 10 | bharatpur
# Processing Record 3 of Set 10 | bonfim
# Processing Record 4 of Set 10 | naryan-mar
# Processing Record 5 of Set 10 | debre tabor
# Processing Record 6 of Set 10 | hovd
# Processing Record 7 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 8 of Set 10 | cumberland
# Processing Record 9 of Set 10 | nyurba
# Processing Record 10 of Set 10 | hailar
# Processing Record 11 of Set 10 | inta
# Processing Record 12 of Set 10 | san jose
# Processing Record 13 of Set 10 | skibbereen
# Processing Record 14 of Set 10 | zheleznodorozhnyy
# Processing Record 15 of Set 10 | marsa matruh
# Processing Record 16 of Set 10 | rebrikha
# Processing Record 17 of Set 10 | iquique
# Processing Record 18 of Set 10 | shelburne
# Processing Record 19 of Set 10 | homer
# Processing Record 20 of Set 10 | barinas
# Processing Record 21 of Set 10 | harrogate
# Processing Record 22 of Set 10 | bubaque
# Processing Record 23 of Set 10 | guayanilla
# Processing Record 24 of Set 10 | savannah bight
# Processing Record 25 of Set 10 | sterling
# Processing Record 26 of Set 10 | martinsburg
# Processing Record 27 of Set 10 | hit
# Processing Record 28 of Set 10 | machado
# Processing Record 29 of Set 10 | waling
# Processing Record 30 of Set 10 | mirabad
# Processing Record 31 of Set 10 | kaili
# Processing Record 32 of Set 10 | belur
# Processing Record 33 of Set 10 | amboasary
# Processing Record 34 of Set 10 | srednekolymsk
# Processing Record 35 of Set 10 | pacific grove
# Processing Record 36 of Set 10 | henties bay
# Processing Record 37 of Set 10 | starachowice
# Processing Record 38 of Set 10 | pecos
# Processing Record 39 of Set 10 | strezhevoy
# Processing Record 40 of Set 10 | kuna
# Processing Record 41 of Set 10 | alofi
# Processing Record 42 of Set 10 | russkaya polyana
# Processing Record 43 of Set 10 | talawdi
# City not found. Skipping...
# Processing Record 44 of Set 10 | rockingham
# Processing Record 45 of Set 10 | levittown
# Processing Record 46 of Set 10 | sibu
# Processing Record 47 of Set 10 | cidreira
# Processing Record 48 of Set 10 | sao joao do piaui
# Processing Record 49 of Set 10 | dhidhdhoo
# Processing Record 50 of Set 10 | havoysund
# Processing Record 1 of Set 11 | dolinsk
# Processing Record 2 of Set 11 | hassleholm
# Processing Record 3 of Set 11 | te anau
# Processing Record 4 of Set 11 | makushino
# Processing Record 5 of Set 11 | zhangye
# Processing Record 6 of Set 11 | cap malheureux
# Processing Record 7 of Set 11 | kirkuk
# Processing Record 8 of Set 11 | visnes
# Processing Record 9 of Set 11 | vedaranniyam
# City not found. Skipping...
# Processing Record 10 of Set 11 | bajil
# Processing Record 11 of Set 11 | pismo beach
# Processing Record 12 of Set 11 | bereda
# Processing Record 13 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 14 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 15 of Set 11 | aborlan
# Processing Record 16 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 17 of Set 11 | roebourne
# Processing Record 18 of Set 11 | kandara
# Processing Record 19 of Set 11 | atambua
# Processing Record 20 of Set 11 | koroni
# Processing Record 21 of Set 11 | mut
# Processing Record 22 of Set 11 | puunsi
# City not found. Skipping...
# Processing Record 23 of Set 11 | zhicheng
# Processing Record 24 of Set 11 | kirakira
# Processing Record 25 of Set 11 | pangnirtung
# Processing Record 26 of Set 11 | brae
# Processing Record 27 of Set 11 | lupiro
# Processing Record 28 of Set 11 | jingdezhen
# Processing Record 29 of Set 11 | vaitape
# Processing Record 30 of Set 11 | magadan
# Processing Record 31 of Set 11 | eureka
# Processing Record 32 of Set 11 | lima
# Processing Record 33 of Set 11 | dauphin
# Processing Record 34 of Set 11 | pavilosta
# Processing Record 35 of Set 11 | akdagmadeni
# Processing Record 36 of Set 11 | chiang rai
# Processing Record 37 of Set 11 | louth
# Processing Record 38 of Set 11 | bjornevatn
# Processing Record 39 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 11 | gollere
# City not found. Skipping...
# Processing Record 41 of Set 11 | sola
# Processing Record 42 of Set 11 | sompeta
# Processing Record 43 of Set 11 | tromso
# Processing Record 44 of Set 11 | veraval
# Processing Record 45 of Set 11 | berlevag
# Processing Record 46 of Set 11 | ondjiva
# Processing Record 47 of Set 11 | kavaratti
# Processing Record 48 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 11 | muli
# Processing Record 50 of Set 11 | istria
# Processing Record 1 of Set 12 | rio gallegos
# Processing Record 2 of Set 12 | whitehorse
# Processing Record 3 of Set 12 | rio claro
# Processing Record 4 of Set 12 | mehamn
# Processing Record 5 of Set 12 | yumen
# Processing Record 6 of Set 12 | coos bay
# Processing Record 7 of Set 12 | praia
# Processing Record 8 of Set 12 | purpe
# Processing Record 9 of Set 12 | baikunthpur
# Processing Record 10 of Set 12 | champerico
# Processing Record 11 of Set 12 | zambezi
# Processing Record 12 of Set 12 | santiago
# Processing Record 13 of Set 12 | kemise
# Processing Record 14 of Set 12 | ust-tsilma
# Processing Record 15 of Set 12 | sur
# Processing Record 16 of Set 12 | marawi
# Processing Record 17 of Set 12 | ostersund
# Processing Record 18 of Set 12 | yabrud
# Processing Record 19 of Set 12 | wanaka
# Processing Record 20 of Set 12 | listvyanka
# Processing Record 21 of Set 12 | preston
# Processing Record 22 of Set 12 | tahoua
# Processing Record 23 of Set 12 | tocopilla
# Processing Record 24 of Set 12 | dubbo
# Processing Record 25 of Set 12 | katherine
# Processing Record 26 of Set 12 | chom bung
# City not found. Skipping...
# Processing Record 27 of Set 12 | ankang
# Processing Record 28 of Set 12 | fukue
# Processing Record 29 of Set 12 | imbituba
# Processing Record 30 of Set 12 | shieli
# Processing Record 31 of Set 12 | magway
# Processing Record 32 of Set 12 | tual
# Processing Record 33 of Set 12 | kiama
# Processing Record 34 of Set 12 | ca mau
# Processing Record 35 of Set 12 | sisimiut
# Processing Record 36 of Set 12 | cockburn town
# Processing Record 37 of Set 12 | tulun
# Processing Record 38 of Set 12 | olinda
# Processing Record 39 of Set 12 | tadine
# Processing Record 40 of Set 12 | gifhorn
# Processing Record 41 of Set 12 | tazovskiy
# Processing Record 42 of Set 12 | nha trang
# Processing Record 43 of Set 12 | micheweni
# Processing Record 44 of Set 12 | gopalpur
# Processing Record 45 of Set 12 | gat
# Processing Record 46 of Set 12 | vikhorevka
# Processing Record 47 of Set 12 | leh
# Processing Record 48 of Set 12 | vila velha
# Processing Record 49 of Set 12 | montepuez
# Processing Record 50 of Set 12 | scarborough
# Processing Record 1 of Set 13 | pampa
# Processing Record 2 of Set 13 | imuris
# Processing Record 3 of Set 13 | tarauaca
# Processing Record 4 of Set 13 | wanning
# Processing Record 5 of Set 13 | noyabrsk
# Processing Record 6 of Set 13 | mlalo
# Processing Record 7 of Set 13 | devils lake
# Processing Record 8 of Set 13 | boa vista
# Processing Record 9 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 13 | coquimbo
# Processing Record 11 of Set 13 | soyo
# Processing Record 12 of Set 13 | cocentaina
# Processing Record 13 of Set 13 | santa rosa
# Processing Record 14 of Set 13 | rockport
# Processing Record 15 of Set 13 | vila franca do campo
# Processing Record 16 of Set 13 | barstow
# Processing Record 17 of Set 13 | umm kaddadah
# Processing Record 18 of Set 13 | koltubanovskiy
# Processing Record 19 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 20 of Set 13 | dori
# Processing Record 21 of Set 13 | ginda
# Processing Record 22 of Set 13 | anqiu
# Processing Record 23 of Set 13 | bathsheba
# Processing Record 24 of Set 13 | xinzhi
# Processing Record 25 of Set 13 | axim
# Processing Record 26 of Set 13 | yinchuan
# Processing Record 27 of Set 13 | constancia
# Processing Record 28 of Set 13 | candolim
# Processing Record 29 of Set 13 | lapua
# Processing Record 30 of Set 13 | constantine
# Processing Record 31 of Set 13 | estelle
# Processing Record 32 of Set 13 | byron bay
# Processing Record 33 of Set 13 | koutsouras
# Processing Record 34 of Set 13 | tuscaloosa
# Processing Record 35 of Set 13 | marfino
# Processing Record 36 of Set 13 | matagami
# Processing Record 37 of Set 13 | tarime
# Processing Record 38 of Set 13 | aksu
# Processing Record 39 of Set 13 | saint-avold
# Processing Record 40 of Set 13 | newala
# Processing Record 41 of Set 13 | biltine
# Processing Record 42 of Set 13 | sakakah
# Processing Record 43 of Set 13 | puerto baquerizo moreno
# Processing Record 44 of Set 13 | qui nhon
# Processing Record 45 of Set 13 | riyadh
# Processing Record 46 of Set 13 | lagoa
# Processing Record 47 of Set 13 | mount pleasant
# Processing Record 48 of Set 13 | puerto escondido
# Processing Record 49 of Set 13 | san policarpo
# Processing Record 50 of Set 13 | taoudenni
# Processing Record 1 of Set 14 | villa carlos paz
# Processing Record 2 of Set 14 | jalpan
# Processing Record 3 of Set 14 | ojitlan
# City not found. Skipping...
# Processing Record 4 of Set 14 | svetlogorsk
# Processing Record 5 of Set 14 | atasu
# Processing Record 6 of Set 14 | sucua
# Processing Record 7 of Set 14 | mwinilunga
# Processing Record 8 of Set 14 | bontang
# Processing Record 9 of Set 14 | buenos aires
# Processing Record 10 of Set 14 | thunder bay
# Processing Record 11 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 14 | chiriguana
# Processing Record 13 of Set 14 | kikwit
# Processing Record 14 of Set 14 | komsomolskiy
# Processing Record 15 of Set 14 | sindou
# Processing Record 16 of Set 14 | huambo
# Processing Record 17 of Set 14 | batsfjord
# Processing Record 18 of Set 14 | ugoofaaru
# Processing Record 19 of Set 14 | coronel bogado
# Processing Record 20 of Set 14 | jackson
# Processing Record 21 of Set 14 | segezha
# Processing Record 22 of Set 14 | umm lajj
# Processing Record 23 of Set 14 | goure
# Processing Record 24 of Set 14 | banjar
# Processing Record 25 of Set 14 | sept-iles
# Processing Record 26 of Set 14 | nioro
# Processing Record 27 of Set 14 | svetlaya
# Processing Record 28 of Set 14 | ibra
# Processing Record 29 of Set 14 | khovu-aksy
# Processing Record 30 of Set 14 | baker city
# Processing Record 31 of Set 14 | sorong
# Processing Record 32 of Set 14 | waddan
# Processing Record 33 of Set 14 | manturovo
# Processing Record 34 of Set 14 | tha rua
# Processing Record 35 of Set 14 | bay-khaak
# Processing Record 36 of Set 14 | kaeo
# Processing Record 37 of Set 14 | conakry
# Processing Record 38 of Set 14 | salinopolis
# Processing Record 39 of Set 14 | mandurah
# Processing Record 40 of Set 14 | guelengdeng
# City not found. Skipping...
# Processing Record 41 of Set 14 | praia da vitoria
# Processing Record 42 of Set 14 | mochudi
# Processing Record 43 of Set 14 | cordoba
# Processing Record 44 of Set 14 | touho
# Processing Record 45 of Set 14 | vanino
# Processing Record 46 of Set 14 | paamiut
# Processing Record 47 of Set 14 | marmaron
# City not found. Skipping...
# Processing Record 48 of Set 14 | bac lieu
# Processing Record 49 of Set 14 | elizabeth city
# Processing Record 50 of Set 14 | minsk
# Processing Record 1 of Set 15 | tautira
# Processing Record 2 of Set 15 | launceston
# Processing Record 3 of Set 15 | foumban
# Processing Record 4 of Set 15 | lerwick
# Processing Record 5 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 6 of Set 15 | phibun mangsahan
# Processing Record 7 of Set 15 | cherskiy
# Processing Record 8 of Set 15 | kismayo
# Processing Record 9 of Set 15 | saint-augustin
# Processing Record 10 of Set 15 | nanjing
# Processing Record 11 of Set 15 | yangambi
# Processing Record 12 of Set 15 | marshfield
# Processing Record 13 of Set 15 | havelock
# Processing Record 14 of Set 15 | talara
# Processing Record 15 of Set 15 | sabang
# Processing Record 16 of Set 15 | caxito
# Processing Record 17 of Set 15 | punta alta
# Processing Record 18 of Set 15 | beloha
# Processing Record 19 of Set 15 | villaviciosa
# Processing Record 20 of Set 15 | bourail
# Processing Record 21 of Set 15 | santa rosalia
# Processing Record 22 of Set 15 | itoigawa
# Processing Record 23 of Set 15 | bongandanga
# Processing Record 24 of Set 15 | ola
# Processing Record 25 of Set 15 | santa cruz
# Processing Record 26 of Set 15 | wajima
# Processing Record 27 of Set 15 | alyangula
# Processing Record 28 of Set 15 | abu dhabi
# Processing Record 29 of Set 15 | kodarma
# Processing Record 30 of Set 15 | dataganj
# Processing Record 31 of Set 15 | saint-ambroise
# Processing Record 32 of Set 15 | a
# City not found. Skipping...
# Processing Record 33 of Set 15 | yenagoa
# Processing Record 34 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 35 of Set 15 | pontianak
# Processing Record 36 of Set 15 | tsabong
# Processing Record 37 of Set 15 | mulki
# Processing Record 38 of Set 15 | marsh harbour
# Processing Record 39 of Set 15 | ewo
# Processing Record 40 of Set 15 | ippy
# Processing Record 41 of Set 15 | vanimo
# Processing Record 42 of Set 15 | vlakhokerasea
# City not found. Skipping...
# Processing Record 43 of Set 15 | mata
# Processing Record 44 of Set 15 | tarko-sale
# Processing Record 45 of Set 15 | portland
# Processing Record 46 of Set 15 | belogorsk
# Processing Record 47 of Set 15 | crotone
# Processing Record 48 of Set 15 | opuwo
# Processing Record 49 of Set 15 | lorengau
# Processing Record 50 of Set 15 | sudak
# Processing Record 1 of Set 16 | sadiqabad
# Processing Record 2 of Set 16 | tukrah
# Processing Record 3 of Set 16 | santiago de cao
# Processing Record 4 of Set 16 | manokwari
# Processing Record 5 of Set 16 | chapleau
# Processing Record 6 of Set 16 | hualmay
# Processing Record 7 of Set 16 | tabialan
# City not found. Skipping...
# Processing Record 8 of Set 16 | motril
# Processing Record 9 of Set 16 | bantou
# Processing Record 10 of Set 16 | barpali
# Processing Record 11 of Set 16 | ankazoabo
# Processing Record 12 of Set 16 | dongsheng
# Processing Record 13 of Set 16 | gebre guracha
# Processing Record 14 of Set 16 | ono
# Processing Record 15 of Set 16 | touros
# Processing Record 16 of Set 16 | mazulskiy
# City not found. Skipping...
# Processing Record 17 of Set 16 | tagusao
# Processing Record 18 of Set 16 | egvekinot
# Processing Record 19 of Set 16 | norman wells
# Processing Record 20 of Set 16 | hofn
# Processing Record 21 of Set 16 | outlook
# Processing Record 22 of Set 16 | dossor
# Processing Record 23 of Set 16 | sawtell
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 712

# %%
# Convert the array of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         Nome      US  64.50 -165.41     12.20        85           1
# 1  Brunsbuttel      DE  53.90    9.15     63.00        93         100
# 2        Bluff      NZ -46.60  168.33     55.99        68          27
# 3        Kapaa      US  22.08 -159.32     75.00       100          90
# 4       Barrow      US  71.29 -156.79     26.60        68          75
# 5     Tomatlan      MX  19.93 -105.25     75.65        91           4
# 6   Bredasdorp      ZA -34.53   20.04     64.40        82          99
# 7          Eyl      SO   7.98   49.82     83.05        50           0
# 8     Hermanus      ZA -34.42   19.23     64.00        84          97
# 9     Zhigansk      RU  66.77  123.37      2.70        92         100
#
#    Wind Speed Current Description
# 0        4.61           clear sky
# 1        8.01     overcast clouds
# 2        8.99    scattered clouds
# 3        9.17          light rain
# 4       12.75       broken clouds
# 5        3.47           clear sky
# 6       10.29     overcast clouds
# 7       15.55           clear sky
# 8        4.00     overcast clouds
# 9       22.15     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_DataBase.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
